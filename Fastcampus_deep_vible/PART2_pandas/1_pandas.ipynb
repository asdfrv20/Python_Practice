# %% [markdown]
# #1.Mount Drive(Google Drive)
# - 좌측의 '코트 스니펫(<>)'에서 "google drive" 검색 후, "Mounting Google Drive in..." 더블 클릭하여 코드 가져오기
# - 또는 '파일'에서 3번째 위치한 구글 드라이블 로고가 있는 파일 클릭

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %% [markdown]
# 리눅스 명령 ls -al: 현재 디렉터리의 파일 및 폴더 확인하기

# %%
ls -al '/content/drive/MyDrive/Python_Practice/Fastcampus_deep_vible/data'
# Out:
# total 1904211
# -rw------- 1 root root     11389 Jul 21 11:13 ETC_영업소_1일_1일_20210720.zip
# -rw------- 1 root root 783889122 Jul 21 12:31 TCS_영업소간통행시간_1시간_1개월_202001.csv
# -rw------- 1 root root 152940227 Jul 21 11:17 TCS_영업소간통행시간_1시간_1개월_202001.zip
# -rw------- 1 root root 133180226 Jul 21 11:17 TCS_영업소간통행시간_1시간_1개월_202002.zip
# -rw------- 1 root root 738556069 Jul 21 12:32 TCS_영업소간통행시간_1시간_1개월_202003.csv
# -rw------- 1 root root 141333004 Jul 21 11:17 TCS_영업소간통행시간_1시간_1개월_202003.zip

# %% [markdown]
# 파일 경로를 쉽게 하기 위해서 Fasdcampus_deep_vible로 경로 이동

# %% [markdown]
# 현재 경로 확인하기

# %%
pwd
# Out:
# '/content'

# %% [markdown]
# #2. Load data

# %%
import pandas as pd

# %%
# Load a file under "data" folder
file = "/content/drive/MyDrive/Python_Practice/Fastcampus_deep_vible/data/TCS_영업소간통행시간_1시간_1개월_202001.csv"
data = pd.read_csv(file, sep=",", encoding='euc-kr')    # pd.read_csv: csv파일을 불러오는 pandas 명령    
                                                        # euc-kr: 한글에 대한 encoding 방식

# %% [markdown]
# 아래는 pandas에서 자주 사용하는 명령들

# %%
# .head(): data의 앞(상위)에서 5개 데이터 보여주기 
data.head()
# Out:
#        집계일자  집계시  출발영업소코드  도착영업소코드  TCS차종구분코드  통행시간  Unnamed: 6
# 0  20200101   17        0      101          3    -1         NaN
# 1  20200101   17        0      101          1    -1         NaN
# 2  20200101    9        0      101          2    -1         NaN
# 3  20200101    9        0      101          1    -1         NaN
# 4  20200101    7        0      101          1    -1         NaN

# %%
# .tail():data의 뒤(하위)에서 5개 데이터 보여주기
data.tail()
# Out:
#               집계일자  집계시  출발영업소코드  도착영업소코드  TCS차종구분코드   통행시간  Unnamed: 6
# 25596211  20200131    9      272      641          1   8388         NaN
# 25596212  20200131   15      137      245          3   2341         NaN
# 25596213  20200131    6      127      612          5  42535         NaN
# 25596214  20200131    6      671      127          1   9494         NaN
# 25596215  20200131   17      212      253          3    833         NaN

# %%
# .info(): pandas로 가져온 data의 정보를 확인할 수 있는 메서드: .info()
# 아래를 확인해보면 엄청 큰 데이터 사이즈를 간편하게 (명령어 몇 개로) 제어하는 것을 볼 수 있음.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25596216 entries, 0 to 25596215
# Data columns (total 7 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   집계일자        int64
#  1   집계시         int64
#  2   출발영업소코드     int64
#  3   도착영업소코드     int64
#  4   TCS차종구분코드   int64
#  5   통행시간        int64
#  6   Unnamed: 6  float64
# dtypes: float64(1), int64(6)
# memory usage: 1.3 GB
