# %% [markdown]
# # Hello python
# ## hello python
# ### hello python
# #### hello python

# %% [markdown]
# 1. Bold 효과 주기
#
# **python is really cool**
#
# 2. 기울임(이테릭체) 효과 주기
#
# *python is really cool*
#
# 3. 항목 설정하기
#   - python
#    - pandas
#       - depth1
#       - depth2
#   - java
#   - c++
#   - golang
# 4. 숫자가 있는 항목 설정하기
#    1. python
#    2. java
#    3. c++
#
# 5. 인용구호 설정
#
# > 파이썬은 재밋다고 하더라...
#
# 6. Markdown에서 "수학기호" 표시하기
#
# $y = 3x$
#
#
# 7. 코드로 인식시켜 출력하기 (주의! '가 아니라 ESC 아래 있는 ` 임)
#
# ```python
# a = 10
# print(a)
# ```
#
# 8. 하이퍼링크 설정하기
#
# - 단순히 링크 url 가져오기: https://www.python.org/
# - 특정 문장에 링크 걸기(대괄호와 소괄호 사용하기): [파이썬 공식 홈페이지](https://www.python.org/)

# %%
a = 10
print(a)
# Out:
# 10

# %%
a = 10
print(a)
# Out:
# 10
